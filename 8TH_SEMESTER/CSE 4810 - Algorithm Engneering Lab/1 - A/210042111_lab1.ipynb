# %% [markdown]
# **210042111   LAB 1**

# %% [markdown]
# task 1

# %%
def next_greater_element(arr):
    n = len(arr)
    result = [-1] * n
    stack = []

    for i in range(n):
        while stack and arr[i] > arr[stack[-1]]:
            idx = stack.pop()
            result[idx] = arr[i]
        stack.append(i)


    return result

print(next_greater_element([1, 3, 2, 4]))
print(next_greater_element([6, 8, 0, 1, 3]))
# Out:
# [3, 4, 4, -1]
# [8, -1, 1, 3, -1]

# %% [markdown]
# Task 2

# %%
from collections import deque

class StackUsingQueues:
    def __init__(self):
        self.q1 = deque()
        self.q2 = deque()

    def push(self, x):
        self.q2.append(x)
        while self.q1:
            self.q2.append(self.q1.popleft())
        self.q1, self.q2 = self.q2, self.q1

    def pop(self):
        if self.q1:
            return self.q1.popleft()
        return None

s = StackUsingQueues()
s.push(10)
s.push(20)
s.push(30)
s.push(40)
print("Pop:", s.pop())
s.push(50)
s.push(60)
print("Pop:", s.pop())
# Out:
# Pop: 30
# Pop: 50

# %% [markdown]
# Task 3

# %%
from collections import deque

def first_non_repeating(s):
    count = {}
    order = deque()
    result = []

    for ch in s:
        print( count.get(ch, 0))
        count[ch] = count.get(ch, 0) + 1


        if count[ch] == 1:
            order.append(ch)


        while order and count[order[0]] > 1:
            order.popleft()


        result.append(order[0] if order else '#')

    return ''.join(result)

print(first_non_repeating("abaacdde"))
print(first_non_repeating("bb"))
# Out:
# 0
# 0
# 1
# 2
# 0
# 0
# 1
# 0
# aabbbbbb
# 0
# 1
# b#
